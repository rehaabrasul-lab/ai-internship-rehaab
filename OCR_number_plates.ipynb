# %% [markdown]
# <a href="https://colab.research.google.com/github/rehaabrasul-lab/ai-internship-rehaab/blob/main/OCR_number_plates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install easyocr

# %%
import easyocr

# %%
reader = easyocr.Reader(['en'])

# %%
result = reader.readtext('https://www.evanshalshaw.com/-/media/evanshalshaw/blog/illegal-number-plates-in-the-uk/illegal-plates-1080x1080px-5.jpg?h=720&w=1280&rev=e71fe4cb2aaa4773b280900b4c8a7c5b&hash=2B6DFCA1B2B54F7A3990D320B6C7AFA5', detail=0)
print(result)
# Out:
# Progress: |██████████████████████████████████████████████████| 101.4% Complete['EH23 LSG']

# %%
result = reader.readtext('https://www.motorfinanceonline.com/wp-content/uploads/sites/6/2025/12/uknumberplate-shutterstock_2326460053.jpg', detail=0)
print(result)
# Out:
# Progress: |███████████████████████████████████████████████████| 103.0% Complete['F', 'XGZ 8812', 'Charles Hurst Group']
