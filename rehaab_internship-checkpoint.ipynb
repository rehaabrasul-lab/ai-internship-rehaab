# %%
#import panda library and matplotlib for plotting 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#downloading an excel sheet with some data and converting it to a DataFrame
file = r"C:\Users\rehaa\Downloads\Animal Rescue incidents attended by LFB from Jan 2009.csv.xlsx"
df = pd.read_excel(file)

# %%
#displays the data frame
df
# Out:
#         IncidentNumber      DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0               139091 2009-01-01 03:01:00     2009  2008/09  Special Service
# 1               275091 2009-01-01 08:51:00     2009  2008/09  Special Service
# 2              2075091 2009-01-04 10:07:00     2009  2008/09  Special Service
# 3              2872091 2009-01-05 12:27:00     2009  2008/09  Special Service
# 4              3553091 2009-01-06 15:23:00     2009  2008/09  Special Service
# ...                ...                 ...      ...      ...              ...
# 13465  077708-30042026 2026-04-30 07:39:00     2026  2026/27  Special Service
# 13466  077715-30042026 2026-04-30 07:52:00     2026  2026/27  Special Service
# 13467  077855-30042026 2026-04-30 11:49:00     2026  2026/27  Special Service
# 13468  078214-30042026 2026-04-30 17:03:00     2026  2026/27  Special Service
# 13469  078256-30042026 2026-04-30 18:17:00     2026  2026/27  Special Service
#
# ...

# %%
#displays the data types for the data frame
df.dtypes
# Out:
# IncidentNumber                        object
# DateTimeOfCall                datetime64[ns]
# CalYear                                int64
# FinYear                               object
# TypeOfIncident                        object
# PumpCount                            float64
# PumpHoursTotal                       float64
# HourlyNotionalCost(£)                float64
# IncidentNotionalCost(£)              float64
# FinalDescription                      object
# AnimalGroupParent                     object
# OriginofCall                          object
# PropertyType                          object
# PropertyCategory                      object
# SpecialServiceTypeCategory            object
# SpecialServiceType                    object
# WardCode                              object
# Ward                                  object
# BoroughCode                           object
# Borough                               object
# StnGroundName                         object
# ...

# %%
#displayes the first few records of the date and time of call when an animal had to be rescued
df["DateTimeOfCall"].head()
# Out:
# 0   2009-01-01 03:01:00
# 1   2009-01-01 08:51:00
# 2   2009-01-04 10:07:00
# 3   2009-01-05 12:27:00
# 4   2009-01-06 15:23:00
# Name: DateTimeOfCall, dtype: datetime64[ns]

# %%
#to check if the data is sorted chronologically - yes, as it is moving smoothly from left to right
pd.to_datetime(df["DateTimeOfCall"]).plot()
# Out:
# <Axes: >

# %%
#using DATE and TIME OF CALL as the index 
df.set_index("DateTimeOfCall", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7112\3746713006.py in ?()
# ----> 1 df.set_index("DateTimeOfCall", inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['DateTimeOfCall'] are in the columns"

# %%
#making sure it works 
df
# Out:
#                       IncidentNumber  CalYear  FinYear   TypeOfIncident  \
# DateTimeOfCall
# 2009-01-01 03:01:00           139091     2009  2008/09  Special Service
# 2009-01-01 08:51:00           275091     2009  2008/09  Special Service
# 2009-01-04 10:07:00          2075091     2009  2008/09  Special Service
# 2009-01-05 12:27:00          2872091     2009  2008/09  Special Service
# 2009-01-06 15:23:00          3553091     2009  2008/09  Special Service
# ...                              ...      ...      ...              ...
# 2026-04-30 07:39:00  077708-30042026     2026  2026/27  Special Service
# 2026-04-30 07:52:00  077715-30042026     2026  2026/27  Special Service
# 2026-04-30 11:49:00  077855-30042026     2026  2026/27  Special Service
# 2026-04-30 17:03:00  078214-30042026     2026  2026/27  Special Service
# 2026-04-30 18:17:00  078256-30042026     2026  2026/27  Special Service
#
#                      PumpCount  PumpHoursTotal  HourlyNotionalCost(£)  \
# ...

# %%
#showing all the incidents in jan 2009 and what happened for each time
df.loc["2021-01-01":"2021-01-31","FinalDescription"]
# Out:
# DateTimeOfCall
# 2021-01-01 12:09:00        KITTEN STUCK UP TREE  AL REQUESTED FROM SCENE
# 2021-01-01 14:06:00                                             Redacted
# 2021-01-03 18:40:00                CAT WITH LEG TRAPPED IN BATH PLUGHOLE
# 2021-01-04 13:39:00                                             Redacted
# 2021-01-06 10:22:00                                             Redacted
# 2021-01-06 13:09:00    CAT IN DISTRESS ON ROOF - ADDITIONAL APPLIANCE...
# 2021-01-06 20:35:00        DOG TRAPPED IN FOX HOLE  - MEET AT CLUB HOUSE
# 2021-01-07 23:50:00                   KITTEN STUCK BETWEEN WALL AND ROOF
# 2021-01-09 08:01:00                                  DOG STUCK IN TRENCH
# 2021-01-10 19:27:00                                             Redacted
# 2021-01-12 11:39:00                                             Redacted
# 2021-01-12 22:38:00                                 CAT TRAPPED IN DITCH
# 2021-01-16 18:05:00                          DOG TRAPPED IN PORTER CABIN
# ...

# %%
#plotting a graph to show monthly calls over the years 
df.resample("ME")["IncidentNumber"].count().plot(title="Monthly Calls")
plt.show()
